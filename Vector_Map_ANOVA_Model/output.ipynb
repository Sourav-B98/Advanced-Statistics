# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import mpldatacursor
# %matplotlib inline

# %%
output = pd.read_csv("output.csv")
output.head(4)
# Out:
#                 locations    x_global    y_global
# 0  akhandananda bhawan NE  693.617856  2150.13955
# 1  akhandananda bhawan NW  527.224356  2110.24405
# 2  akhandananda bhawan SE  690.196356  2212.81955
# 3  akhandananda bhawan SW  497.592856  2191.16355

# %%
img = cv2.imread('stitched_images/stitched.png')

# %%
plt.figure(figsize = (20,20))
plt.imshow(img)
plt.plot(np.array(output["x_global"])+150,output["y_global"],'r*')
